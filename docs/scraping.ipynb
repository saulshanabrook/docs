# %% [markdown]
# # MA Eviction Notices
#
# Here will we talk about how to automate pulling data from a massachusetts trial court website to track eviction cases.
#
# The website search looks like this:
#
# ![5d35a53006278849e1d74d5769dbbe4d80e454d6-1.jpg](attachment:3dbfe234-f286-4ebf-a979-a38826265c3d.jpg)
